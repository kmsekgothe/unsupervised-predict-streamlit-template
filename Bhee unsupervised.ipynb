# %%
pip install comet_ml
# Out:
# Collecting comet_mlNote: you may need to restart the kernel to use updated packages.
#   Downloading comet_ml-3.24.0-py2.py3-none-any.whl (314 kB)
# Collecting everett[ini]>=1.0.1
#   Downloading everett-2.0.1-py2.py3-none-any.whl (33 kB)
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Requirement already satisfied: six in c:\users\xps14\anaconda3\lib\site-packages (from comet_ml) (1.15.0)
# Collecting requests-toolbelt>=0.8.0
#   Downloading requests_toolbelt-0.9.1-py2.py3-none-any.whl (54 kB)
# Collecting semantic-version>=2.8.0
#   Downloading semantic_version-2.8.5-py2.py3-none-any.whl (15 kB)
# Collecting wurlitzer>=1.0.2
#   Downloading wurlitzer-3.0.2-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: requests>=2.18.4 in c:\users\xps14\anaconda3\lib\site-packages (from comet_ml) (2.25.1)
# Collecting dulwich>=0.20.6
#   Downloading dulwich-0.20.30-cp38-cp38-win_amd64.whl (490 kB)
# Requirement already satisfied: wrapt>=1.11.2 in c:\users\xps14\anaconda3\lib\site-packages (from comet_ml) (1.12.1)
# Requirement already satisfied: jsonschema!=3.1.0,>=2.6.0 in c:\users\xps14\anaconda3\lib\site-packages (from comet_ml) (3.2.0)
# Collecting websocket-client>=0.55.0
#   Downloading websocket_client-1.2.3-py3-none-any.whl (53 kB)
#
# Requirement already satisfied: certifi in c:\users\xps14\anaconda3\lib\site-packages (from dulwich>=0.20.6->comet_ml) (2020.12.5)
# Requirement already satisfied: urllib3>=1.24.1 in c:\users\xps14\anaconda3\lib\site-packages (from dulwich>=0.20.6->comet_ml) (1.26.4)
# Collecting configobj
#   Downloading configobj-5.0.6.tar.gz (33 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\xps14\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\xps14\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (20.3.0)
# Requirement already satisfied: setuptools in c:\users\xps14\anaconda3\lib\site-packages (from jsonschema!=3.1.0,>=2.6.0->comet_ml) (52.0.0.post20210125)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\xps14\anaconda3\lib\site-packages (from requests>=2.18.4->comet_ml) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\xps14\anaconda3\lib\site-packages (from requests>=2.18.4->comet_ml) (2.10)
# Building wheels for collected packages: nvidia-ml-py3, configobj
#   Building wheel for nvidia-ml-py3 (setup.py): started
#   Building wheel for nvidia-ml-py3 (setup.py): finished with status 'done'
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19191 sha256=460d93f4484f2e0e80f4cd6d48367acc359ab87180b1539970badca40c3db12a
#   Stored in directory: c:\users\xps14\appdata\local\pip\cache\wheels\b9\b1\68\cb4feab29709d4155310d29a421389665dcab9eb3b679b527b
#   Building wheel for configobj (setup.py): started
#   Building wheel for configobj (setup.py): finished with status 'done'
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34547 sha256=4fb27313531bcebe9121d8ad1e4ab6553d3e1a2547d7c22ccc77615858df4a2f
#   Stored in directory: c:\users\xps14\appdata\local\pip\cache\wheels\34\2a\24\a490264ae9041fd48f778ff393526572c80bb498ddecb07ea5
# Successfully built nvidia-ml-py3 configobj
# Installing collected packages: everett, configobj, wurlitzer, websocket-client, semantic-version, requests-toolbelt, nvidia-ml-py3, dulwich, comet-ml
# Successfully installed comet-ml-3.24.0 configobj-5.0.6 dulwich-0.20.30 everett-2.0.1 nvidia-ml-py3-7.352.0 requests-toolbelt-0.9.1 semantic-version-2.8.5 websocket-client-1.2.3 wurlitzer-3.0.2

# %%
# import comet_ml at the top of your file
from comet_ml import Experiment

# Create an experiment with your api key
experiment = Experiment(
    api_key="tUlD7sThKB1ruPMrpsAUJ5HlO",
    project_name="unsupervised-learning-group-12",
    workspace="mirfaana",
)

# Run your code and go to /
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/mirfaana/unsupervised-learning-group-12/cf1c90bcc4cb49b9af5cbc606cb584cc

# %%
#libraries
import numpy as np
import pandas as pd
from surprise import Dataset
from surprise import SVD
from surprise import Reader
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-2323c29da0c5> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 from surprise import Dataset
#       5 from surprise import SVD
#       6 from surprise import Reader
#
# ModuleNotFoundError: No module named 'surprise'

# %% [markdown]
# We will be using the dataset module which loads the pandas dataframe that is available for this experiment, The reader function is used to parse a file containing ratings data. The default format in which it accepts data is that each rating is stored in a separate line in the order user, movie and rating
#
# SVD = singular value decomposition
#
# conda install -c conda-forge scikit-surprise

# %%
#Loading data
movies=pd.read_csv('movies.csv')
tags=pd.read_csv('tags.csv')
train=pd.read_csv('train.csv')
genome_s=pd.read_csv('genome_scores.csv')
genome_t=pd.read_csv('genome_tags.csv')
imdb=pd.read_csv('imdb_data.csv')
test_df=pd.read_csv('test.csv')
links=pd.read_csv('links.csv')
sub=pd.read_csv('sample_submission.csv')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movies.info()
movies.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   title    62423 non-null  object
#  2   genres   62423 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB
# movieId    0
# title      0
# genres     0
# dtype: int64

# %%
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
tags.info()
tags.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093360 entries, 0 to 1093359
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   userId     1093360 non-null  int64
#  1   movieId    1093360 non-null  int64
#  2   tag        1093344 non-null  object
#  3   timestamp  1093360 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 33.4+ MB
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64

# %%
train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %%
train.info()
train.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000038 entries, 0 to 10000037
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 305.2 MB
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64

# %%
genome_t.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
genome_t.info()
genome_t.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tagId   1128 non-null   int64
#  1   tag     1128 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.8+ KB
# tagId    0
# tag      0
# dtype: int64

# %%
genome_s.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
genome_s.info()
genome_s.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15584448 entries, 0 to 15584447
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   movieId    int64
#  1   tagId      int64
#  2   relevance  float64
# dtypes: float64(1), int64(2)
# memory usage: 356.7 MB
# movieId      0
# tagId        0
# relevance    0
# dtype: int64

# %%
imdb.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        2  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        3  Walter Matthau|Jack Lemmon|Sophia Loren|Ann-Ma...
# 3        4  Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        5  Steve Martin|Diane Keaton|Martin Short|Kimberl...
#
#               director  runtime       budget  \
# 0        John Lasseter     81.0  $30,000,000
# 1   Jonathan Hensleigh    104.0  $65,000,000
# 2  Mark Steven Johnson    101.0  $25,000,000
# 3       Terry McMillan    124.0  $16,000,000
# 4       Albert Hackett    106.0  $30,000,000
#
#                                        plot_keywords
# 0                   toy|rivalry|cowboy|cgi animation
# 1                   board game|adventurer|fight|game
# 2                         boat|lake|neighbor|rivalry
# 3  black american|husband wife relationship|betra...
# 4                    fatherhood|doberman|dog|mansion

# %%
imdb.info()
imdb.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movieId        27278 non-null  int64
#  1   title_cast     17210 non-null  object
#  2   director       17404 non-null  object
#  3   runtime        15189 non-null  float64
#  4   budget         7906 non-null   object
#  5   plot_keywords  16200 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ MB
# movieId              0
# title_cast       10068
# director          9874
# runtime          12089
# budget           19372
# plot_keywords    11078
# dtype: int64

# %%
test.head()
# Out:
#    userId  movieId
# 0       1     2011
# 1       1     4144
# 2       1     5767
# 3       1     6711
# 4       1     7318

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000019 entries, 0 to 5000018
# Data columns (total 2 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   userId   int64
#  1   movieId  int64
# dtypes: int64(2)
# memory usage: 76.3 MB

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
links.info()
links.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   imdbId   62423 non-null  int64
#  2   tmdbId   62316 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB
# movieId      0
# imdbId       0
# tmdbId     107
# dtype: int64

# %%
#sample submission
sub.head()
# Out:
#        Id  rating
# 0  1_2011     1.0
# 1  1_4144     1.0
# 2  1_5767     1.0
# 3  1_6711     1.0
# 4  1_7318     1.0

# %%
df_train = train.copy()

# %% [raw]
# movie_data = pd.merge(train1, movies, on='movieId')

# %%
#For understanding the data, below the train dataframe is merged with the movies dataframe
df = df_train.merge(movies, on = 'movieId', how= 'left')
df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837
#
#                                                title  \
# 0                                   In Bruges (2008)
# 1                 Father of the Bride Part II (1995)
# 2  Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (...
# 3     Miss Congeniality 2: Armed and Fabulous (2005)
# 4  Wes Craven's New Nightmare (Nightmare on Elm S...
#
#                           genres
# 0    Comedy|Crime|Drama|Thriller
# 1                         Comedy
# 2           Action|Comedy|Sci-Fi
# 3         Adventure|Comedy|Crime
# 4  Drama|Horror|Mystery|Thriller

# %%
df= train.merge(movies,
            on='movieId', 
            how='left'
            ).merge(imdb,
            on='movieId',
            how= 'left'
            )
df.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837
#
#                                                title  \
# 0                                   In Bruges (2008)
# 1                 Father of the Bride Part II (1995)
# 2  Men in Black II (a.k.a. MIIB) (a.k.a. MIB 2) (...
# 3     Miss Congeniality 2: Armed and Fabulous (2005)
# 4  Wes Craven's New Nightmare (Nightmare on Elm S...
#
#                           genres  \
# 0    Comedy|Crime|Drama|Thriller
# 1                         Comedy
# 2           Action|Comedy|Sci-Fi
# 3         Adventure|Comedy|Crime
# 4  Drama|Horror|Mystery|Thriller
#
#                                           title_cast           director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...    Martin McDonagh
# 1  Steve Martin|Diane Keaton|Martin Short|Kimberl...     Albert Hackett
# 2  Tommy Lee Jones|Will Smith|Rip Torn|Lara Flynn...  Lowell Cunningham
# 3  Sandra Bullock|Regina King|Enrique Murciano|Wi...      Marc Lawrence
# 4  Jeff Davis|Heather Langenkamp|Miko Hughes|Matt...         Wes Craven
#
#    runtime        budget                                      plot_keywords
# 0    107.0   $15,000,000                          dwarf|bruges|irish|hitman
# 1    106.0   $30,000,000                    fatherhood|doberman|dog|mansion
# 2     88.0  $140,000,000  lingerie|michael jackson character|shorthaired...
# 3    115.0   $45,000,000       female protagonist|cleave gag|good woman|fbi
# 4    112.0    $8,000,000  freddy krueger|elm street|famous director as h...

# %%
# Loading as Surprise dataframe
reader = Reader()
# Data selected for model training
data = Dataset.load_from_df(df_train[['userId', 'movieId', 'rating']], reader)

# %%
from surprise.model_selection import train_test_split

# %%
# Data split 90/10
trainset, testset = train_test_split(data, test_size=0.1)

# %%
# Base algorithm
base = SVD()

# %%
# Fitting our trainset
base.fit(trainset)

# %%
predictions = base.test(testset) 
predictions

test = pd.DataFrame(predictions)

# %%
test.head()
# Out:
#       uid    iid  r_ui       est                    details
# 0  127503   1625   5.0  4.214120  {'was_impossible': False}
# 1  151902  27700   1.5  3.221665  {'was_impossible': False}
# 2   80445    911   4.5  4.450628  {'was_impossible': False}
# 3   50324   2002   4.5  3.780394  {'was_impossible': False}
# 4   97533  58559   4.5  3.824964  {'was_impossible': False}

# %%
# We are trying to predict ratings for every userId / movieId pair, we implement the below list comprehension to achieve this.
ratings_predictions=[base.predict(row.userId, row.movieId) for _,row in test_df.iterrows()]
ratings_predictions
# Out:
# [Prediction(uid=1, iid=2011, r_ui=None, est=3.423038838924612, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4144, r_ui=None, est=4.401046378286214, details={'was_impossible': False}),
#  Prediction(uid=1, iid=5767, r_ui=None, est=3.613016181464389, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6711, r_ui=None, est=3.7448986713894623, details={'was_impossible': False}),
#  Prediction(uid=1, iid=7318, r_ui=None, est=2.9616553290210454, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8405, r_ui=None, est=4.158051847891909, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8786, r_ui=None, est=4.0028096482361555, details={'was_impossible': False}),
#  Prediction(uid=2, iid=150, r_ui=None, est=3.5970174869408083, details={'was_impossible': False}),
#  Prediction(uid=2, iid=356, r_ui=None, est=4.068294664498523, details={'was_impossible': False}),
#  Prediction(uid=2, iid=497, r_ui=None, est=3.503605443693033, details={'was_impossible': False}),
#  Prediction(uid=2, iid=588, r_ui=None, est=3.24604959210807, details={'was_impossible': False}),
#  Prediction(uid=2, iid=653, r_ui=None, est=3.068055951287422, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1080, r_ui=None, est=3.762808811817159, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1196, r_ui=None, est=4.363673961397999, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1198, r_ui=None, est=4.221783632779289, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1201, r_ui=None, est=4.113929313666307, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1299, r_ui=None, est=3.494963519630108, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1485, r_ui=None, est=3.1451185878960723, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1580, r_ui=None, est=3.686234022682891, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1693, r_ui=None, est=3.7270397295839524, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2028, r_ui=None, est=4.0612332967243026, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2083, r_ui=None, est=3.182006750026973, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2617, r_ui=None, est=3.773692881907393, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2640, r_ui=None, est=2.7821424668218073, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2918, r_ui=None, est=3.7166799557456454, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3098, r_ui=None, est=3.7742419113600194, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3114, r_ui=None, est=3.023695153030964, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3510, r_ui=None, est=3.561783296339182, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3994, r_ui=None, est=3.5258754828822867, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4103, r_ui=None, est=3.6430378701698816, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4963, r_ui=None, est=3.8994082849535756, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5103, r_ui=None, est=3.437110160173915, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5955, r_ui=None, est=3.3157568854890584, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6156, r_ui=None, est=2.916963409767406, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6287, r_ui=None, est=2.9958911426108656, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6311, r_ui=None, est=3.301811506289934, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6753, r_ui=None, est=3.352315258729459, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7075, r_ui=None, est=3.7471975496589005, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7153, r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7386, r_ui=None, est=3.4095412771629796, details={'was_impossible': False}),
#  Prediction(uid=2, iid=8961, r_ui=None, est=3.966002978138975, details={'was_impossible': False}),
#  Prediction(uid=2, iid=30848, r_ui=None, est=3.643316680341744, details={'was_impossible': False}),
#  Prediction(uid=2, iid=33493, r_ui=None, est=3.9965162244778285, details={'was_impossible': False}),
#  Prediction(uid=2, iid=34162, r_ui=None, est=3.624773631242491, details={'was_impossible': False}),
#  Prediction(uid=2, iid=40815, r_ui=None, est=4.388102693886412, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1, r_ui=None, est=3.6050246042897736, details={'was_impossible': False}),
#  Prediction(uid=3, iid=260, r_ui=None, est=4.089869570958362, details={'was_impossible': False}),
#  Prediction(uid=3, iid=858, r_ui=None, est=4.4982714983867025, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1198, r_ui=None, est=3.9584259410099527, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1201, r_ui=None, est=4.39935739812952, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1214, r_ui=None, est=4.1495866268885315, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1217, r_ui=None, est=4.501765062018156, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1221, r_ui=None, est=4.450811275973292, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1222, r_ui=None, est=4.315884483151728, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1676, r_ui=None, est=3.6987179908194685, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1909, r_ui=None, est=3.3631664897663254, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1960, r_ui=None, est=4.18171945170527, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3471, r_ui=None, est=3.6360615811125085, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3534, r_ui=None, est=3.4005003620931067, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3730, r_ui=None, est=4.321546790456778, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3785, r_ui=None, est=3.1235135813006045, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3948, r_ui=None, est=3.3756257205664593, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3979, r_ui=None, est=2.716459978399954, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4025, r_ui=None, est=2.79546964180273, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4148, r_ui=None, est=3.5258844709583843, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4383, r_ui=None, est=4.0789562027373245, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4816, r_ui=None, est=3.270949637753507, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4979, r_ui=None, est=4.114731461565734, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5219, r_ui=None, est=3.7475939874421917, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5254, r_ui=None, est=3.3930207777127848, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5291, r_ui=None, est=4.631247833772465, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5313, r_ui=None, est=2.8520780875795757, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5364, r_ui=None, est=3.5497083712247344, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5479, r_ui=None, est=3.7732958760761797, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5528, r_ui=None, est=3.839343711923944, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5669, r_ui=None, est=4.130776963679035, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5679, r_ui=None, est=3.6232759242189934, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5782, r_ui=None, est=4.379970879352606, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5872, r_ui=None, est=3.3781360546989383, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5900, r_ui=None, est=2.98379427562677, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5944, r_ui=None, est=3.6110208263253902, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5954, r_ui=None, est=4.288885148094427, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6213, r_ui=None, est=3.458829339649581, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6323, r_ui=None, est=4.032025144083211, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6541, r_ui=None, est=3.297885808313902, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6586, r_ui=None, est=3.3288361513549956, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6934, r_ui=None, est=3.726140998704949, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6952, r_ui=None, est=3.2913533077651347, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7163, r_ui=None, est=3.528152642827118, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7438, r_ui=None, est=4.073943820050431, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7439, r_ui=None, est=3.5080173828290517, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7445, r_ui=None, est=3.999379899991962, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8360, r_ui=None, est=3.514214761883008, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8368, r_ui=None, est=3.894092065160999, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8370, r_ui=None, est=4.408127846013565, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8529, r_ui=None, est=3.9157879820305825, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8641, r_ui=None, est=3.5159779758518543, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8861, r_ui=None, est=3.3337860079659336, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8874, r_ui=None, est=4.234613817753116, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27706, r_ui=None, est=3.908529511426167, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27793, r_ui=None, est=2.5646217210960027, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31184, r_ui=None, est=3.8164632698937067, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31685, r_ui=None, est=3.294651985294737, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31696, r_ui=None, est=3.9779139745075094, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31804, r_ui=None, est=3.728263036627145, details={'was_impossible': False}),
#  Prediction(uid=3, iid=33615, r_ui=None, est=3.7293627278254835, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34150, r_ui=None, est=3.0502208372756314, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34162, r_ui=None, est=3.2446540833625455, details={'was_impossible': False}),
#  Prediction(uid=3, iid=35836, r_ui=None, est=3.3959457201391077, details={'was_impossible': False}),
#  Prediction(uid=3, iid=37386, r_ui=None, est=3.417907091852789, details={'was_impossible': False}),
#  Prediction(uid=3, iid=44022, r_ui=None, est=3.5883518562829777, details={'was_impossible': False}),
#  Prediction(uid=3, iid=46972, r_ui=None, est=3.129683538877556, details={'was_impossible': False}),
#  Prediction(uid=3, iid=47610, r_ui=None, est=4.071879079479097, details={'was_impossible': False}),
#  Prediction(uid=3, iid=48780, r_ui=None, est=4.418769343939618, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49272, r_ui=None, est=4.023308527925284, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49278, r_ui=None, est=3.8440296779463425, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49530, r_ui=None, est=4.038936839475743, details={'was_impossible': False}),
#  Prediction(uid=3, iid=51255, r_ui=None, est=4.105881912890606, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53121, r_ui=None, est=3.157572952980611, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53129, r_ui=None, est=3.872956544831218, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53464, r_ui=None, est=3.078050710300563, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55765, r_ui=None, est=4.028318805271945, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55805, r_ui=None, est=4.052103875095348, details={'was_impossible': False}),
#  Prediction(uid=3, iid=58559, r_ui=None, est=4.32240477331856, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59315, r_ui=None, est=3.835121351627442, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59501, r_ui=None, est=3.5922248545147677, details={'was_impossible': False}),
#  Prediction(uid=3, iid=60069, r_ui=None, est=4.059911348841121, details={'was_impossible': False}),
#  Prediction(uid=3, iid=61350, r_ui=None, est=3.4055449051133606, details={'was_impossible': False}),
#  Prediction(uid=3, iid=64839, r_ui=None, est=4.112627171111978, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68319, r_ui=None, est=3.8271706795649374, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68793, r_ui=None, est=3.1456733863397464, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68952, r_ui=None, est=3.309821504104391, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71057, r_ui=None, est=4.031198331506829, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71464, r_ui=None, est=3.9743123221648036, details={'was_impossible': False}),
#  Prediction(uid=3, iid=72209, r_ui=None, est=3.3533701940251652, details={'was_impossible': False}),
#  Prediction(uid=3, iid=74789, r_ui=None, est=3.8600493763509713, details={'was_impossible': False}),
#  Prediction(uid=3, iid=76077, r_ui=None, est=3.498061556162027, details={'was_impossible': False}),
#  Prediction(uid=3, iid=78499, r_ui=None, est=3.6728613291879, details={'was_impossible': False}),
#  Prediction(uid=3, iid=81845, r_ui=None, est=4.156541489036614, details={'was_impossible': False}),
#  Prediction(uid=3, iid=82202, r_ui=None, est=3.381637531214308, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85020, r_ui=None, est=3.5470225900199224, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85056, r_ui=None, est=3.1430914163078283, details={'was_impossible': False}),
#  Prediction(uid=3, iid=88140, r_ui=None, est=3.4086721015848838, details={'was_impossible': False}),
#  Prediction(uid=3, iid=96610, r_ui=None, est=3.940190546545514, details={'was_impossible': False}),
#  Prediction(uid=3, iid=97225, r_ui=None, est=3.503145001717243, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102445, r_ui=None, est=3.888360701591897, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102880, r_ui=None, est=2.6297652191578567, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102903, r_ui=None, est=3.9299779582651326, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103141, r_ui=None, est=3.687555695285616, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103772, r_ui=None, est=3.8010341938982632, details={'was_impossible': False}),
#  Prediction(uid=3, iid=105213, r_ui=None, est=3.395894973783588, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109374, r_ui=None, est=4.30237847739867, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109487, r_ui=None, est=4.3574112560000975, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111443, r_ui=None, est=3.927936286167391, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111659, r_ui=None, est=3.8202777195104294, details={'was_impossible': False}),
#  Prediction(uid=3, iid=112138, r_ui=None, est=3.6866877941932157, details={'was_impossible': False}),
#  Prediction(uid=3, iid=114847, r_ui=None, est=3.728788583777457, details={'was_impossible': False}),
#  Prediction(uid=3, iid=115569, r_ui=None, est=4.238291637530207, details={'was_impossible': False}),
#  Prediction(uid=3, iid=116897, r_ui=None, est=4.386559641449872, details={'was_impossible': False}),
#  Prediction(uid=3, iid=117529, r_ui=None, est=3.4677152125352566, details={'was_impossible': False}),
#  Prediction(uid=3, iid=122912, r_ui=None, est=4.017325470562443, details={'was_impossible': False}),
#  Prediction(uid=3, iid=135143, r_ui=None, est=3.978099388026439, details={'was_impossible': False}),
#  Prediction(uid=3, iid=136449, r_ui=None, est=4.248643925797073, details={'was_impossible': False}),
#  Prediction(uid=3, iid=143385, r_ui=None, est=3.962042550911061, details={'was_impossible': False}),
#  Prediction(uid=3, iid=151763, r_ui=None, est=4.212654873043184, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1036, r_ui=None, est=3.543207995169654, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1136, r_ui=None, est=4.374373656755031, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1196, r_ui=None, est=4.024336932819501, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1220, r_ui=None, est=3.424403123056577, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1907, r_ui=None, est=3.6665629966360878, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2716, r_ui=None, est=3.532214056984727, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2985, r_ui=None, est=2.9792382069953645, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3114, r_ui=None, est=3.9758870531641977, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3671, r_ui=None, est=3.933387369262862, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4709, r_ui=None, est=3.057332313885441, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4816, r_ui=None, est=3.4008605752077075, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5110, r_ui=None, est=3.6383731452306165, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5418, r_ui=None, est=3.589287180518228, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5903, r_ui=None, est=3.198005156971018, details={'was_impossible': False}),
#  Prediction(uid=4, iid=6863, r_ui=None, est=3.3078416054451614, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7438, r_ui=None, est=3.8349516438607374, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7569, r_ui=None, est=3.5376876817871774, details={'was_impossible': False}),
#  Prediction(uid=4, iid=8665, r_ui=None, est=3.4823393364069926, details={'was_impossible': False}),
#  Prediction(uid=4, iid=34048, r_ui=None, est=2.483478865651427, details={'was_impossible': False}),
#  Prediction(uid=4, iid=45431, r_ui=None, est=3.230542224782266, details={'was_impossible': False}),
#  Prediction(uid=4, iid=49649, r_ui=None, est=2.049665157613785, details={'was_impossible': False}),
#  Prediction(uid=4, iid=53125, r_ui=None, est=2.9313598240923353, details={'was_impossible': False}),
#  Prediction(uid=4, iid=69122, r_ui=None, est=3.7214195685851204, details={'was_impossible': False}),
#  Prediction(uid=4, iid=77561, r_ui=None, est=2.5976182349558954, details={'was_impossible': False}),
#  Prediction(uid=4, iid=82461, r_ui=None, est=2.5271759560866003, details={'was_impossible': False}),
#  Prediction(uid=4, iid=83134, r_ui=None, est=3.592678436950858, details={'was_impossible': False}),
#  Prediction(uid=4, iid=85414, r_ui=None, est=3.277845995768512, details={'was_impossible': False}),
#  Prediction(uid=4, iid=86345, r_ui=None, est=4.721077825559379, details={'was_impossible': False}),
#  Prediction(uid=4, iid=88125, r_ui=None, est=3.8081745502034283, details={'was_impossible': False}),
#  Prediction(uid=4, iid=91529, r_ui=None, est=3.4742178735282967, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93510, r_ui=None, est=3.4444670857736286, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93840, r_ui=None, est=3.4445738748064967, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96079, r_ui=None, est=3.2584698433098067, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96737, r_ui=None, est=2.9346617640999386, details={'was_impossible': False}),
#  Prediction(uid=4, iid=97304, r_ui=None, est=3.7731015006095823, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103228, r_ui=None, est=2.42099878870248, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103772, r_ui=None, est=2.2680575754876577, details={'was_impossible': False}),
#  Prediction(uid=4, iid=109487, r_ui=None, est=3.7192243500958657, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111759, r_ui=None, est=3.1784809781635683, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111781, r_ui=None, est=2.7356581444468357, details={'was_impossible': False}),
#  Prediction(uid=4, iid=112852, r_ui=None, est=3.0248632051517785, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122882, r_ui=None, est=3.784453758061464, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122918, r_ui=None, est=3.109130254771321, details={'was_impossible': False}),
#  Prediction(uid=4, iid=134130, r_ui=None, est=3.4005717967591695, details={'was_impossible': False}),
#  Prediction(uid=4, iid=136020, r_ui=None, est=2.8472497204675467, details={'was_impossible': False}),
#  Prediction(uid=4, iid=148626, r_ui=None, est=3.800635834341475, details={'was_impossible': False}),
#  Prediction(uid=4, iid=156706, r_ui=None, est=2.704386086851347, details={'was_impossible': False}),
#  Prediction(uid=4, iid=159817, r_ui=None, est=4.481621912411085, details={'was_impossible': False}),
#  Prediction(uid=4, iid=189333, r_ui=None, est=3.6415752641719434, details={'was_impossible': False}),
#  Prediction(uid=5, iid=36, r_ui=None, est=4.258996771334493, details={'was_impossible': False}),
#  Prediction(uid=5, iid=122, r_ui=None, est=3.079846043901762, details={'was_impossible': False}),
#  Prediction(uid=5, iid=147, r_ui=None, est=3.947519289568264, details={'was_impossible': False}),
#  Prediction(uid=5, iid=191, r_ui=None, est=3.081694742781541, details={'was_impossible': False}),
#  Prediction(uid=5, iid=218, r_ui=None, est=3.5439953482928246, details={'was_impossible': False}),
#  Prediction(uid=5, iid=231, r_ui=None, est=2.8302246882215014, details={'was_impossible': False}),
#  Prediction(uid=5, iid=248, r_ui=None, est=3.389385019013933, details={'was_impossible': False}),
#  Prediction(uid=5, iid=253, r_ui=None, est=3.674145389598688, details={'was_impossible': False}),
#  Prediction(uid=5, iid=277, r_ui=None, est=3.5866840641213766, details={'was_impossible': False}),
#  Prediction(uid=5, iid=333, r_ui=None, est=3.2817580082540503, details={'was_impossible': False}),
#  Prediction(uid=5, iid=337, r_ui=None, est=4.283907921516104, details={'was_impossible': False}),
#  Prediction(uid=5, iid=344, r_ui=None, est=2.90422635204794, details={'was_impossible': False}),
#  Prediction(uid=5, iid=372, r_ui=None, est=3.5410472366188883, details={'was_impossible': False}),
#  Prediction(uid=5, iid=435, r_ui=None, est=3.1088853735923814, details={'was_impossible': False}),
#  Prediction(uid=5, iid=441, r_ui=None, est=3.999474633496259, details={'was_impossible': False}),
#  Prediction(uid=5, iid=457, r_ui=None, est=4.217044875018969, details={'was_impossible': False}),
#  Prediction(uid=5, iid=491, r_ui=None, est=3.545879706417168, details={'was_impossible': False}),
#  Prediction(uid=5, iid=608, r_ui=None, est=4.610579128229174, details={'was_impossible': False}),
#  Prediction(uid=5, iid=628, r_ui=None, est=3.898536717300037, details={'was_impossible': False}),
#  Prediction(uid=5, iid=780, r_ui=None, est=3.3708903647612614, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1016, r_ui=None, est=3.408174207046612, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1196, r_ui=None, est=4.518817016238432, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1235, r_ui=None, est=4.570642506256158, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1270, r_ui=None, est=4.043884280479767, details={'was_impossible': False}),
#  Prediction(uid=6, iid=161, r_ui=None, est=3.988139465894517, details={'was_impossible': False}),
#  Prediction(uid=6, iid=260, r_ui=None, est=4.873996877727081, details={'was_impossible': False}),
#  Prediction(uid=6, iid=608, r_ui=None, est=4.128271267650285, details={'was_impossible': False}),
#  Prediction(uid=6, iid=919, r_ui=None, est=4.549892010615675, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1466, r_ui=None, est=3.884787522603774, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1704, r_ui=None, est=4.467189019918179, details={'was_impossible': False}),
#  Prediction(uid=7, iid=17, r_ui=None, est=4.11695938088311, details={'was_impossible': False}),
#  Prediction(uid=7, iid=165, r_ui=None, est=3.3585344299348883, details={'was_impossible': False}),
#  Prediction(uid=7, iid=185, r_ui=None, est=3.2316505544487173, details={'was_impossible': False}),
#  Prediction(uid=7, iid=308, r_ui=None, est=4.061352812477124, details={'was_impossible': False}),
#  Prediction(uid=7, iid=590, r_ui=None, est=3.3101502613698783, details={'was_impossible': False}),
#  Prediction(uid=8, iid=10, r_ui=None, est=3.7554386417645516, details={'was_impossible': False}),
#  Prediction(uid=8, iid=25, r_ui=None, est=3.761657560487294, details={'was_impossible': False}),
#  Prediction(uid=8, iid=27, r_ui=None, est=3.2802271376717114, details={'was_impossible': False}),
#  Prediction(uid=8, iid=50, r_ui=None, est=4.507299695556083, details={'was_impossible': False}),
#  Prediction(uid=8, iid=69, r_ui=None, est=3.77915334275567, details={'was_impossible': False}),
#  Prediction(uid=8, iid=207, r_ui=None, est=3.6252733738502747, details={'was_impossible': False}),
#  Prediction(uid=8, iid=237, r_ui=None, est=3.512515215095399, details={'was_impossible': False}),
#  Prediction(uid=8, iid=260, r_ui=None, est=3.7595297882613816, details={'was_impossible': False}),
#  Prediction(uid=8, iid=356, r_ui=None, est=4.3258895985108055, details={'was_impossible': False}),
#  Prediction(uid=8, iid=440, r_ui=None, est=3.4207447070823624, details={'was_impossible': False}),
#  Prediction(uid=8, iid=588, r_ui=None, est=3.305175602686139, details={'was_impossible': False}),
#  Prediction(uid=8, iid=593, r_ui=None, est=4.133155765162213, details={'was_impossible': False}),
#  Prediction(uid=8, iid=750, r_ui=None, est=4.260042987370443, details={'was_impossible': False}),
#  Prediction(uid=8, iid=923, r_ui=None, est=4.053784880736695, details={'was_impossible': False}),
#  Prediction(uid=8, iid=953, r_ui=None, est=3.5542546925703435, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1020, r_ui=None, est=3.326816999137517, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1047, r_ui=None, est=4.027615021622032, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1092, r_ui=None, est=3.6397566426678414, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1210, r_ui=None, est=4.047547454453569, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1240, r_ui=None, est=4.011992103215498, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1259, r_ui=None, est=3.8550210431184784, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1287, r_ui=None, est=3.6357866305847306, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1358, r_ui=None, est=3.5615471283796394, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1370, r_ui=None, est=3.7986427777030625, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1485, r_ui=None, est=3.6074770867564805, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1552, r_ui=None, est=3.932561021891072, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1573, r_ui=None, est=4.1093961659274845, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1584, r_ui=None, est=3.6688754972828264, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1616, r_ui=None, est=3.3148171518374916, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1625, r_ui=None, est=4.240175240878099, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1645, r_ui=None, est=3.621670972992769, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1747, r_ui=None, est=3.939856970294105, details={'was_impossible': False}),
#  Prediction(uid=9, iid=10, r_ui=None, est=3.761130786125256, details={'was_impossible': False}),
#  Prediction(uid=9, iid=61, r_ui=None, est=4.1331611180922705, details={'was_impossible': False}),
#  Prediction(uid=9, iid=105, r_ui=None, est=3.911219769456195, details={'was_impossible': False}),
#  Prediction(uid=9, iid=116, r_ui=None, est=4.3424248558979714, details={'was_impossible': False}),
#  Prediction(uid=9, iid=161, r_ui=None, est=4.310682514732986, details={'was_impossible': False}),
#  Prediction(uid=9, iid=260, r_ui=None, est=4.293461640194719, details={'was_impossible': False}),
#  Prediction(uid=9, iid=355, r_ui=None, est=3.096500491648821, details={'was_impossible': False}),
#  Prediction(uid=9, iid=356, r_ui=None, est=4.599179573429759, details={'was_impossible': False}),
#  Prediction(uid=9, iid=366, r_ui=None, est=3.2835803964382357, details={'was_impossible': False}),
#  Prediction(uid=9, iid=378, r_ui=None, est=3.965373712651067, details={'was_impossible': False}),
#  Prediction(uid=9, iid=387, r_ui=None, est=3.248410103794, details={'was_impossible': False}),
#  Prediction(uid=9, iid=435, r_ui=None, est=3.2354194708937087, details={'was_impossible': False}),
#  Prediction(uid=9, iid=454, r_ui=None, est=4.300268468825898, details={'was_impossible': False}),
#  Prediction(uid=9, iid=466, r_ui=None, est=2.7189570831987675, details={'was_impossible': False}),
#  Prediction(uid=9, iid=474, r_ui=None, est=4.178546505030559, details={'was_impossible': False}),
#  Prediction(uid=9, iid=516, r_ui=None, est=3.7786631150265935, details={'was_impossible': False}),
#  Prediction(uid=9, iid=541, r_ui=None, est=4.000743981326722, details={'was_impossible': False}),
#  Prediction(uid=9, iid=590, r_ui=None, est=4.151356132930982, details={'was_impossible': False}),
#  Prediction(uid=9, iid=592, r_ui=None, est=3.611253746223109, details={'was_impossible': False}),
#  Prediction(uid=9, iid=594, r_ui=None, est=4.192197708358426, details={'was_impossible': False}),
#  Prediction(uid=9, iid=597, r_ui=None, est=4.515329476908135, details={'was_impossible': False}),
#  Prediction(uid=9, iid=616, r_ui=None, est=3.8952642403282285, details={'was_impossible': False}),
#  Prediction(uid=9, iid=667, r_ui=None, est=2.8833069642521156, details={'was_impossible': False}),
#  Prediction(uid=9, iid=852, r_ui=None, est=3.6977314118897597, details={'was_impossible': False}),
#  Prediction(uid=9, iid=971, r_ui=None, est=3.888707846251678, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1005, r_ui=None, est=3.326295675570835, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1010, r_ui=None, est=3.836371193553846, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1011, r_ui=None, est=3.3599581678993307, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1018, r_ui=None, est=3.823650308435915, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1028, r_ui=None, est=4.273060251156048, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1079, r_ui=None, est=3.794222465757596, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1097, r_ui=None, est=4.143479180932742, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1101, r_ui=None, est=4.1332975290876535, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1124, r_ui=None, est=4.2924631340432935, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1125, r_ui=None, est=3.7059790706278615, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1127, r_ui=None, est=4.16597231900338, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1200, r_ui=None, est=4.177259048152227, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1221, r_ui=None, est=4.093210128788327, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1222, r_ui=None, est=4.016803172328374, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1258, r_ui=None, est=3.994905860310296, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1298, r_ui=None, est=4.116347229759007, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1299, r_ui=None, est=4.023779867362164, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1347, r_ui=None, est=3.739563798108869, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1372, r_ui=None, est=3.6326359156744714, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1376, r_ui=None, est=4.093671048631291, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1381, r_ui=None, est=2.808166464845703, details={'was_impossible': False}),
#  Prediction(uid=10, iid=260, r_ui=None, est=4.243038065168752, details={'was_impossible': False}),
#  Prediction(uid=10, iid=380, r_ui=None, est=3.52954370633145, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1186, r_ui=None, est=3.4021797947420764, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2094, r_ui=None, est=3.1109943091526846, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2505, r_ui=None, est=2.916763671782095, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2605, r_ui=None, est=3.0232200207087008, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2707, r_ui=None, est=3.5664331245546363, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2944, r_ui=None, est=3.444287210125865, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4361, r_ui=None, est=3.317454653869163, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5049, r_ui=None, est=3.1946794109794814, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6383, r_ui=None, est=2.183512441930871, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6953, r_ui=None, est=3.63664537657382, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7444, r_ui=None, est=2.791733948894051, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7566, r_ui=None, est=4.172905203037035, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53953, r_ui=None, est=3.4312475178129103, details={'was_impossible': False}),
#  Prediction(uid=11, iid=1207, r_ui=None, est=3.4394662972622694, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2329, r_ui=None, est=3.984880152720772, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2581, r_ui=None, est=2.991834151481753, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2881, r_ui=None, est=3.102293483336716, details={'was_impossible': False}),
#  Prediction(uid=11, iid=4210, r_ui=None, est=2.952246651254196, details={'was_impossible': False}),
#  Prediction(uid=11, iid=33669, r_ui=None, est=3.17632592736407, details={'was_impossible': False}),
#  Prediction(uid=11, iid=42723, r_ui=None, est=2.4150458586278054, details={'was_impossible': False}),
#  Prediction(uid=12, iid=7, r_ui=None, est=2.8113360211451903, details={'was_impossible': False}),
#  Prediction(uid=12, iid=21, r_ui=None, est=3.5805513946561227, details={'was_impossible': False}),
#  Prediction(uid=12, iid=47, r_ui=None, est=4.245632263894821, details={'was_impossible': False}),
#  Prediction(uid=12, iid=50, r_ui=None, est=4.5040902084981385, details={'was_impossible': False}),
#  Prediction(uid=12, iid=141, r_ui=None, est=3.39201114027645, details={'was_impossible': False}),
#  Prediction(uid=12, iid=160, r_ui=None, est=1.7264820603723616, details={'was_impossible': False}),
#  Prediction(uid=12, iid=163, r_ui=None, est=3.2632862727468095, details={'was_impossible': False}),
#  Prediction(uid=12, iid=203, r_ui=None, est=2.843111654833948, details={'was_impossible': False}),
#  Prediction(uid=12, iid=238, r_ui=None, est=2.46074294264716, details={'was_impossible': False}),
#  Prediction(uid=12, iid=268, r_ui=None, est=3.1592091264782596, details={'was_impossible': False}),
#  Prediction(uid=12, iid=292, r_ui=None, est=2.7721670477780256, details={'was_impossible': False}),
#  Prediction(uid=12, iid=293, r_ui=None, est=4.151725276194688, details={'was_impossible': False}),
#  Prediction(uid=12, iid=344, r_ui=None, est=1.9541963435339484, details={'was_impossible': False}),
#  Prediction(uid=12, iid=374, r_ui=None, est=1.360706681018054, details={'was_impossible': False}),
#  Prediction(uid=12, iid=376, r_ui=None, est=3.102028412791688, details={'was_impossible': False}),
#  Prediction(uid=12, iid=380, r_ui=None, est=2.992244162731968, details={'was_impossible': False}),
#  Prediction(uid=12, iid=477, r_ui=None, est=3.473102164573328, details={'was_impossible': False}),
#  Prediction(uid=12, iid=497, r_ui=None, est=3.9386277022355385, details={'was_impossible': False}),
#  Prediction(uid=12, iid=538, r_ui=None, est=3.946797649615394, details={'was_impossible': False}),
#  Prediction(uid=12, iid=575, r_ui=None, est=2.672935462118116, details={'was_impossible': False}),
#  Prediction(uid=12, iid=592, r_ui=None, est=3.182448556314458, details={'was_impossible': False}),
#  Prediction(uid=12, iid=603, r_ui=None, est=2.5774518438697798, details={'was_impossible': False}),
#  Prediction(uid=12, iid=608, r_ui=None, est=4.47634878767302, details={'was_impossible': False}),
#  Prediction(uid=12, iid=613, r_ui=None, est=3.4239207603371686, details={'was_impossible': False}),
#  Prediction(uid=12, iid=765, r_ui=None, est=2.054263059089985, details={'was_impossible': False}),
#  Prediction(uid=12, iid=778, r_ui=None, est=4.2392599320589275, details={'was_impossible': False}),
#  Prediction(uid=12, iid=780, r_ui=None, est=2.8115423691468444, details={'was_impossible': False}),
#  Prediction(uid=12, iid=858, r_ui=None, est=4.687924437361719, details={'was_impossible': False}),
#  Prediction(uid=12, iid=932, r_ui=None, est=3.8104806223777548, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1013, r_ui=None, est=2.9767601712433396, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1015, r_ui=None, est=2.847529514409496, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1057, r_ui=None, est=3.671519465861277, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1135, r_ui=None, est=2.7125535453996408, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1136, r_ui=None, est=4.202718954198093, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1183, r_ui=None, est=3.5301958994839615, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1188, r_ui=None, est=3.8418987219810896, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1194, r_ui=None, est=3.4612231679852914, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1200, r_ui=None, est=4.108127991199661, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1225, r_ui=None, est=4.1741167222680335, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1230, r_ui=None, est=4.068897854743919, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1231, r_ui=None, est=3.740240756424514, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1243, r_ui=None, est=3.986269980671839, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1258, r_ui=None, est=4.08529918010126, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1265, r_ui=None, est=3.5623872662333707, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1267, r_ui=None, est=4.418160926370945, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1270, r_ui=None, est=3.797061977958702, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1387, r_ui=None, est=3.9214072665665483, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1391, r_ui=None, est=2.310405917160556, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1393, r_ui=None, est=3.4543919728787866, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1394, r_ui=None, est=3.9969288009547728, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1474, r_ui=None, est=1.230667682947453, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1552, r_ui=None, est=2.5430148061357567, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1586, r_ui=None, est=2.628736693169533, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1596, r_ui=None, est=3.324342419758117, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1644, r_ui=None, est=1.6636178534562935, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1665, r_ui=None, est=2.3067051865616612, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1682, r_ui=None, est=3.8002444098266577, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1777, r_ui=None, est=2.8537336418347454, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1876, r_ui=None, est=2.1868486601807637, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1884, r_ui=None, est=3.7535596865020033, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1947, r_ui=None, est=4.066034929374958, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2052, r_ui=None, est=3.0662614903612027, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2081, r_ui=None, est=3.2287007560744465, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2108, r_ui=None, est=3.837921384936724, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2174, r_ui=None, est=3.5566718545719116, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2318, r_ui=None, est=3.8454749704337967, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2336, r_ui=None, est=3.9587806444819185, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2374, r_ui=None, est=2.4442391551883236, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2381, r_ui=None, est=1.4807515436810592, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2406, r_ui=None, est=3.285456706919834, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2420, r_ui=None, est=2.9609838727389253, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2459, r_ui=None, est=3.1343790864038774, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2469, r_ui=None, est=3.0001124994319857, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2500, r_ui=None, est=2.2207903973882552, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2599, r_ui=None, est=4.131753045081047, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2762, r_ui=None, est=3.819900049292889, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2770, r_ui=None, est=2.644312606672493, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2797, r_ui=None, est=3.4560679133166046, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2863, r_ui=None, est=3.754848852292012, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2881, r_ui=None, est=2.4292813386983343, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2901, r_ui=None, est=2.6526559679237565, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2948, r_ui=None, est=3.750535449024407, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2987, r_ui=None, est=3.4536636927942586, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3033, r_ui=None, est=3.4600957950422777, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3089, r_ui=None, est=4.061574293136374, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3148, r_ui=None, est=3.733494111998128, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3186, r_ui=None, est=3.6441230302794425, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3249, r_ui=None, est=2.801856054751572, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3255, r_ui=None, est=3.321558342670511, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3262, r_ui=None, est=3.5618858553889643, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3264, r_ui=None, est=2.465974941457481, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3274, r_ui=None, est=2.6259898064485805, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3397, r_ui=None, est=3.6077182701033226, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3435, r_ui=None, est=4.21112642323437, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3478, r_ui=None, est=3.2272956634464474, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3538, r_ui=None, est=3.3332435755183485, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3578, r_ui=None, est=3.6971533812733908, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3608, r_ui=None, est=2.706907138321443, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3633, r_ui=None, est=3.3077925775370303, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3751, r_ui=None, est=3.2460216306038085, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3809, r_ui=None, est=2.6061665101825513, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3823, r_ui=None, est=3.276719052724182, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3897, r_ui=None, est=4.159790344173249, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4022, r_ui=None, est=3.4060922907583246, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4027, r_ui=None, est=4.293556335861883, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4039, r_ui=None, est=3.071231401544813, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4080, r_ui=None, est=2.5455180917430695, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4100, r_ui=None, est=1.752617252016208, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4105, r_ui=None, est=3.711207218896867, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4135, r_ui=None, est=2.971262479899418, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4246, r_ui=None, est=3.4575458992417247, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4378, r_ui=None, est=3.8738538050545372, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4529, r_ui=None, est=3.6934673305789283, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4559, r_ui=None, est=2.2109649626195433, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4703, r_ui=None, est=3.4513262138759253, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5013, r_ui=None, est=3.6585197211448355, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5339, r_ui=None, est=3.7795954865329393, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5459, r_ui=None, est=2.3165387044517836, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5481, r_ui=None, est=2.8142006712488032, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5785, r_ui=None, est=2.6550991371402346, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6268, r_ui=None, est=3.489776706545371, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6296, r_ui=None, est=3.900137138317723, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6297, r_ui=None, est=3.40539855854022, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6539, r_ui=None, est=3.3238894605321647, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6711, r_ui=None, est=4.001194768764036, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6750, r_ui=None, est=2.887643776319637, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6863, r_ui=None, est=3.265913808896838, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6979, r_ui=None, est=3.4882001841923254, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6993, r_ui=None, est=3.887712145397372, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8017, r_ui=None, est=3.649328485655819, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8040, r_ui=None, est=2.889670033934649, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8644, r_ui=None, est=3.1017140517707826, details={'was_impossible': False}),
# ...
#  Prediction(uid=23, iid=1228, r_ui=None, est=4.406039616307924, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1249, r_ui=None, est=3.996236079306508, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1265, r_ui=None, est=4.522320787932328, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1291, r_ui=None, est=4.504320976337556, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1344, r_ui=None, est=4.160781485758057, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1357, r_ui=None, est=4.429388537291391, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1371, r_ui=None, est=3.3484023598381425, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1396, r_ui=None, est=4.310941829017126, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1449, r_ui=None, est=4.246208063410986, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1573, r_ui=None, est=3.7942266651478667, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1584, r_ui=None, est=4.177381771923234, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1617, r_ui=None, est=4.712266977063613, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1625, r_ui=None, est=4.261933495239319, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1641, r_ui=None, est=4.457405089607692, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1673, r_ui=None, est=4.033111859841052, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1729, r_ui=None, est=3.9278712321420697, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1810, r_ui=None, est=3.94150470965732, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1957, r_ui=None, est=4.452097530769577, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2028, r_ui=None, est=4.835111871180559, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2058, r_ui=None, est=3.6619573156066125, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2064, r_ui=None, est=4.301617264893052, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2108, r_ui=None, est=4.081920950965937, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2166, r_ui=None, est=4.3070258318419095, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2245, r_ui=None, est=3.6694056017017225, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2262, r_ui=None, est=3.622193579862661, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2294, r_ui=None, est=3.630836014862589, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2301, r_ui=None, est=4.150381871013268, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2336, r_ui=None, est=4.435697615560823, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2411, r_ui=None, est=3.4301444456870316, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2417, r_ui=None, est=3.7264104143856622, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2470, r_ui=None, est=3.5798430476517957, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2528, r_ui=None, est=3.7570667483746774, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2611, r_ui=None, est=4.325123235940355, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2692, r_ui=None, est=4.408254083888678, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2797, r_ui=None, est=4.443308371295455, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2871, r_ui=None, est=4.104052873511463, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2928, r_ui=None, est=4.005824762192095, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2942, r_ui=None, est=3.63270702488041, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3019, r_ui=None, est=3.9215481640600705, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3060, r_ui=None, est=4.1873777127269705, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3105, r_ui=None, est=4.3693657635151535, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3135, r_ui=None, est=4.30916446632769, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3142, r_ui=None, est=3.9088423623029125, details={'was_impossible': False}),
#  Prediction(uid=24, iid=50, r_ui=None, est=4.419243052768535, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1221, r_ui=None, est=4.476663362728774, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1918, r_ui=None, est=3.383585938577908, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2490, r_ui=None, est=3.603051832818157, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2581, r_ui=None, est=3.811066498463343, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3623, r_ui=None, est=3.284713494757401, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3863, r_ui=None, est=3.2523547166221163, details={'was_impossible': False}),
#  Prediction(uid=24, iid=58559, r_ui=None, est=4.303926823627138, details={'was_impossible': False}),
#  Prediction(uid=25, iid=21, r_ui=None, est=3.47334821339516, details={'was_impossible': False}),
#  Prediction(uid=25, iid=25, r_ui=None, est=3.531485499845645, details={'was_impossible': False}),
#  Prediction(uid=25, iid=110, r_ui=None, est=3.6653676335025307, details={'was_impossible': False}),
#  Prediction(uid=25, iid=150, r_ui=None, est=3.4179848205714736, details={'was_impossible': False}),
#  Prediction(uid=25, iid=161, r_ui=None, est=3.4053620359081926, details={'was_impossible': False}),
#  Prediction(uid=25, iid=185, r_ui=None, est=3.2206505880968477, details={'was_impossible': False}),
#  Prediction(uid=25, iid=215, r_ui=None, est=4.022497682505769, details={'was_impossible': False}),
#  Prediction(uid=25, iid=260, r_ui=None, est=3.5106561481373566, details={'was_impossible': False}),
#  Prediction(uid=25, iid=261, r_ui=None, est=3.386027640479995, details={'was_impossible': False}),
#  Prediction(uid=25, iid=292, r_ui=None, est=3.412862919544896, details={'was_impossible': False}),
#  Prediction(uid=25, iid=315, r_ui=None, est=3.102617616385493, details={'was_impossible': False}),
#  Prediction(uid=25, iid=380, r_ui=None, est=3.3042036883111896, details={'was_impossible': False}),
#  Prediction(uid=25, iid=432, r_ui=None, est=2.93934409963097, details={'was_impossible': False}),
#  Prediction(uid=25, iid=457, r_ui=None, est=3.822910994425269, details={'was_impossible': False}),
#  Prediction(uid=25, iid=480, r_ui=None, est=3.365333812162793, details={'was_impossible': False}),
#  Prediction(uid=25, iid=595, r_ui=None, est=3.3453420754705854, details={'was_impossible': False}),
#  Prediction(uid=26, iid=455, r_ui=None, est=2.596454773036663, details={'was_impossible': False}),
#  Prediction(uid=26, iid=590, r_ui=None, est=3.721470975226649, details={'was_impossible': False}),
#  Prediction(uid=26, iid=1270, r_ui=None, est=4.137528555488358, details={'was_impossible': False}),
#  Prediction(uid=26, iid=2382, r_ui=None, est=2.139270824672469, details={'was_impossible': False}),
#  Prediction(uid=26, iid=4951, r_ui=None, est=3.3926609363988285, details={'was_impossible': False}),
#  Prediction(uid=26, iid=72249, r_ui=None, est=3.6272976339067573, details={'was_impossible': False}),
#  Prediction(uid=27, iid=260, r_ui=None, est=4.024692323844933, details={'was_impossible': False}),
#  Prediction(uid=27, iid=356, r_ui=None, est=4.175242080610703, details={'was_impossible': False}),
#  Prediction(uid=27, iid=597, r_ui=None, est=3.947895024057269, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1008, r_ui=None, est=3.684486107539949, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1082, r_ui=None, est=4.195363187807713, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1101, r_ui=None, est=3.8304282056172734, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1196, r_ui=None, est=3.987657376653395, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1931, r_ui=None, est=4.428653938831163, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1952, r_ui=None, est=4.362495396584497, details={'was_impossible': False}),
#  Prediction(uid=27, iid=2145, r_ui=None, est=3.6660397333287897, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3098, r_ui=None, est=3.953328299452979, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3365, r_ui=None, est=4.315036362081382, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3671, r_ui=None, est=4.245729877431238, details={'was_impossible': False}),
#  Prediction(uid=28, iid=610, r_ui=None, est=4.320581174187409, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1407, r_ui=None, est=3.937177973769971, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1580, r_ui=None, est=4.386027584327226, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1584, r_ui=None, est=4.451492027546321, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1909, r_ui=None, est=4.019378243796752, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2021, r_ui=None, est=4.385176027580725, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2311, r_ui=None, est=4.437166278969428, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2723, r_ui=None, est=3.8403378667577077, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69, r_ui=None, est=3.9290520517683554, details={'was_impossible': False}),
#  Prediction(uid=29, iid=175, r_ui=None, est=3.1850588443709644, details={'was_impossible': False}),
#  Prediction(uid=29, iid=562, r_ui=None, est=3.6568403362514292, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1354, r_ui=None, est=3.5376206486406803, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1619, r_ui=None, est=3.643613793182623, details={'was_impossible': False}),
#  Prediction(uid=29, iid=55553, r_ui=None, est=3.1625579929010765, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69784, r_ui=None, est=2.5557182816376365, details={'was_impossible': False}),
#  Prediction(uid=29, iid=72641, r_ui=None, est=3.938741449673992, details={'was_impossible': False}),
#  Prediction(uid=30, iid=410, r_ui=None, est=3.5760521076016856, details={'was_impossible': False}),
#  Prediction(uid=30, iid=1580, r_ui=None, est=3.576121561740934, details={'was_impossible': False}),
#  Prediction(uid=30, iid=4701, r_ui=None, est=3.608616181154295, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33004, r_ui=None, est=3.71358298666996, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33794, r_ui=None, est=3.7713021726194595, details={'was_impossible': False}),
#  Prediction(uid=30, iid=91542, r_ui=None, est=3.560541486848601, details={'was_impossible': False}),
#  Prediction(uid=31, iid=47, r_ui=None, est=2.582189122485698, details={'was_impossible': False}),
#  Prediction(uid=31, iid=110, r_ui=None, est=2.7696579057470467, details={'was_impossible': False}),
#  Prediction(uid=31, iid=141, r_ui=None, est=2.4768456491562576, details={'was_impossible': False}),
#  Prediction(uid=31, iid=161, r_ui=None, est=2.84249451575005, details={'was_impossible': False}),
#  Prediction(uid=31, iid=253, r_ui=None, est=2.175699224024329, details={'was_impossible': False}),
#  Prediction(uid=31, iid=260, r_ui=None, est=2.5342175116914323, details={'was_impossible': False}),
#  Prediction(uid=31, iid=377, r_ui=None, est=2.698843529708398, details={'was_impossible': False}),
#  Prediction(uid=31, iid=434, r_ui=None, est=2.456694344909874, details={'was_impossible': False}),
#  Prediction(uid=31, iid=454, r_ui=None, est=2.6051741577420158, details={'was_impossible': False}),
#  Prediction(uid=31, iid=474, r_ui=None, est=2.8157918056065285, details={'was_impossible': False}),
#  Prediction(uid=31, iid=587, r_ui=None, est=2.619495093004033, details={'was_impossible': False}),
#  Prediction(uid=31, iid=648, r_ui=None, est=2.3254038794068688, details={'was_impossible': False}),
#  Prediction(uid=31, iid=736, r_ui=None, est=2.6214722384503535, details={'was_impossible': False}),
#  Prediction(uid=31, iid=932, r_ui=None, est=2.788969277081136, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1036, r_ui=None, est=2.7099484293171803, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1079, r_ui=None, est=2.9009654178114688, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1258, r_ui=None, est=2.8405610724222843, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1393, r_ui=None, est=2.846127045953818, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1459, r_ui=None, est=2.486275406103102, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1479, r_ui=None, est=2.040172861192746, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1625, r_ui=None, est=2.7416187714399243, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1641, r_ui=None, est=2.9160997556214476, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1693, r_ui=None, est=2.527246330547093, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1923, r_ui=None, est=2.425912667319822, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2028, r_ui=None, est=2.9029632417071345, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2081, r_ui=None, est=2.6620523175247093, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2141, r_ui=None, est=2.6160298482624356, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2262, r_ui=None, est=1.9787956256616808, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2321, r_ui=None, est=2.3477472728468007, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2396, r_ui=None, est=3.1315602746278635, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2710, r_ui=None, est=1.6836231123646717, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3004, r_ui=None, est=1.4548854245795562, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3081, r_ui=None, est=2.159349415098025, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3175, r_ui=None, est=2.606149065658394, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3206, r_ui=None, est=2.143979279431781, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3253, r_ui=None, est=2.531724681427092, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3408, r_ui=None, est=2.7016519454476833, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3420, r_ui=None, est=2.6353416856942493, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3481, r_ui=None, est=2.800637985765274, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3525, r_ui=None, est=1.9692291942330953, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3755, r_ui=None, est=2.345014657683268, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3793, r_ui=None, est=2.136232168419413, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3841, r_ui=None, est=1.8769118253651165, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4174, r_ui=None, est=2.612648507843836, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4392, r_ui=None, est=2.366214844286651, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4564, r_ui=None, est=2.125697608358002, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4639, r_ui=None, est=1.808555293440143, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4973, r_ui=None, est=3.0605384553942536, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4995, r_ui=None, est=3.025175289896673, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5377, r_ui=None, est=2.800503218787036, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5472, r_ui=None, est=2.520625680830646, details={'was_impossible': False}),
#  ...]

# %%
# Converting our prediction into a familiar format-Dataframe
df_pred=pd.DataFrame(ratings_predictions)
df_pred
# Out:
#             uid   iid  r_ui       est                    details
# 0             1  2011  None  3.423039  {'was_impossible': False}
# 1             1  4144  None  4.401046  {'was_impossible': False}
# 2             1  5767  None  3.613016  {'was_impossible': False}
# 3             1  6711  None  3.744899  {'was_impossible': False}
# 4             1  7318  None  2.961655  {'was_impossible': False}
# ...         ...   ...   ...       ...                        ...
# 5000014  162541  4079  None  3.294863  {'was_impossible': False}
# 5000015  162541  4467  None  3.983922  {'was_impossible': False}
# 5000016  162541  4980  None  2.831535  {'was_impossible': False}
# 5000017  162541  5689  None  2.908624  {'was_impossible': False}
# 5000018  162541  7153  None  4.580570  {'was_impossible': False}
#
# [5000019 rows x 5 columns]

# %%
# Renaming our predictions to original names
df_pred=df_pred.rename(columns={'uid':'userId', 'iid':'movieId','est':'rating'})
df_pred.drop(['r_ui','details'],axis=1,inplace=True)

# %%
# Snippet of our ratings
df_pred.head()
# Out:
#    userId  movieId    rating
# 0       1     2011  3.423039
# 1       1     4144  4.401046
# 2       1     5767  3.613016
# 3       1     6711  3.744899
# 4       1     7318  2.961655

# %%
# Concatenating userId/movieId into a single Id column.(code has to be run twice to get desired outcome)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)
df_pred['Id']=df_pred.apply(lambda x:'%s_%s' % (x['userId'],x['movieId']),axis=1)

# %%
# View the first five rows of the dataframe
df_pred.head()
# Out:
#    userId  movieId    rating      Id
# 0       1     2011  3.423039  1_2011
# 1       1     4144  4.401046  1_4144
# 2       1     5767  3.613016  1_5767
# 3       1     6711  3.744899  1_6711
# 4       1     7318  2.961655  1_7318

# %%
# Drop the columns: 'userId' and 'movieId'
df_pred.drop(['userId', 'movieId'], inplace=True, axis= 1)

# %%
# View the predicted dataset
df_pred = df_pred[['Id', 'rating']]

# %%
# View the first 5 rows
df_pred.head()
# Out:
#        Id    rating
# 0  1_2011  3.423039
# 1  1_4144  4.401046
# 2  1_5767  3.613016
# 3  1_6711  3.744899
# 4  1_7318  2.961655

# %%
# The submitted base model
df_pred.to_csv("SVD_model_base.csv", index=False)

# %%
experiment.end()
# Out:
# COMET INFO: ---------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------
# COMET INFO:   Data:
# COMET INFO:     display_summary_level : 1
# COMET INFO:     url                   : https://www.comet.ml/mirfaana/unsupervised-learning-group-12/cf1c90bcc4cb49b9af5cbc606cb584cc
# COMET INFO:   Uploads:
# COMET INFO:     environment details      : 1
# COMET INFO:     filename                 : 1
# COMET INFO:     git metadata             : 1
# COMET INFO:     git-patch (uncompressed) : 1 (10.63 MB)
# COMET INFO:     installed packages       : 1
# COMET INFO:     notebook                 : 1
# COMET INFO:     source_code              : 1
# COMET INFO: ---------------------------
# COMET INFO: Uploading metrics, params, and assets to Comet before program termination (may take several seconds)
# COMET INFO: The Python SDK has 3600 seconds to finish before aborting...
